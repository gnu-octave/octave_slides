% %% [markdown]
% > "[...] the users have the freedom to run, copy, distribute, study, change and improve the software."
% >
% > Source: https://www.gnu.org/philosophy/free-sw.html

% %%
graphics_toolkit qt
sombrero ();
text (-8, 8, 0.6, "オールフス、カイトーベン", "FontName", "IPAGothic", "FontSize", 20)
text (-8, 8, 0.5, "OHLHUS, Kai Torben", "FontName", "Courier", "FontSize", 20)
text (-8, 8, 0.4, "理学研究科", "FontName", "IPAGothic", "FontSize", 20)
text (-8, 8, 0.3, "Graduate School of Science", "FontName", "Courier", "FontSize", 20)
text (-8, 8, 0.2, "東京女子大学", "FontName", "IPAGothic", "FontSize", 20)
text (-8, 8, 0.1, "Tokyo Woman's Christian University", "FontName", "Courier", "FontSize", 20)
#axis off;
